# %% [markdown]
# <a href="https://colab.research.google.com/github/FDorj/Data-Visualization-with-Python/blob/main/BoxPlot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# download dataset
# !wget https://raw.githubusercontent.com/Njmondoa/Superstore-Sales-Analysis/main/SuperStore_data.csv # web get
# Out:
# --2024-08-03 22:53:29--  https://raw.githubusercontent.com/Njmondoa/Superstore-Sales-Analysis/main/SuperStore_data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2300789 (2.2M) [text/plain]
# Saving to: ‘SuperStore_data.csv’
#
# SuperStore_data.csv 100%[===================>]   2.19M  --.-KB/s    in 0.06s
#
# 2024-08-03 22:53:30 (34.6 MB/s) - ‘SuperStore_data.csv’ saved [2300789/2300789]

# %%
# load and read the dataset
import pandas as pd # pandas is for tabular data sets
df = pd.read_csv('SuperStore_data.csv')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6,3), dpi=100)
sns.boxplot(x = 'Category', y = 'Quantity', data = df)
plt.title('Quantity by Category')
plt.xlabel('Category')
plt.ylabel('Quantity')
plt.show()

# %%
from sklearn.datasets import load_iris

data = load_iris()
x = data.data

plt.figure(figsize=(10,5), dpi=100)

plt.boxplot(x, labels = data.feature_names)

plt.xlabel('Features')
plt.ylabel('Feature Values')
plt.title('Iris Dataset - Boxplot')

plt.show()
