# %% [markdown]
# <a href="https://colab.research.google.com/github/FDorj/Data-Visualization-with-Python/blob/main/Scatter_Plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# download dataset
# !wget https://raw.githubusercontent.com/Njmondoa/Superstore-Sales-Analysis/main/SuperStore_data.csv
# Out:
# --2024-08-03 19:30:09--  https://raw.githubusercontent.com/Njmondoa/Superstore-Sales-Analysis/main/SuperStore_data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2300789 (2.2M) [text/plain]
# Saving to: ‘SuperStore_data.csv’
#
# SuperStore_data.csv 100%[===================>]   2.19M  --.-KB/s    in 0.08s
#
# 2024-08-03 19:30:10 (27.8 MB/s) - ‘SuperStore_data.csv’ saved [2300789/2300789]

# %%
import pandas as pd
df = pd.read_csv('SuperStore_data.csv')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#sns.scatterplot(x = 'Sales', y = 'Profit', data = df)

plt.figure(figsize=(6,3), dpi=100)
sns.scatterplot(x = 'Sales', y = 'Profit', data = df)
plt.title('Sales vs Profit')
plt.show()

# %%
from sklearn.datasets import load_iris

data = load_iris()
# print(data)

petal_length = data.data[:, 2]
petal_width = data.data[:, 3]
labels = data.target

plt.figure(figsize=(6,3), dpi=100)
plt.scatter(petal_length, petal_width, c=labels, cmap='viridis')
plt.title('Petal length VS width')
plt.xlabel('Petal length (cm)')
plt.ylabel('Petal width (cm)')

plt.colorbar(label='Iris Species')
plt.show()
